# %%
import sys
import os
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_theme()

path1 = r'C:\Users\sigbj\Documents\Master\Code'
path2 = r'C:\Users\sigbj\Documents\Master\Code\heat'
sys.path.append(path1)
sys.path.append(path2)

#--resume C:\Users\sigbj\Documents\Master\Code\testing\test_output\ckpt\checkpoint.pth

# %%
from heat.infer import main
root_path = r'test_output/reproject_set'
ckpt_path = r'C:\Users\sigbj\Documents\Master\Code\testing\test_output\ckpt\checkpoint.pth'
for id in os.listdir(root_path):
    data_path = root_path + '/' + id 
    det_path = data_path + '/det'
    viz_base = data_path + r'\results\rgb'
    save_base = data_path + r'\results\viz'   
    main(data_path=data_path,
         det_path=det_path,
         ckpt_path=ckpt_path,
         viz_base=viz_base,
         save_base=save_base)
# Out:
# Load from ckpts of epoch 239
# test
# Loaded saved model from C:\Users\sigbj\Documents\Master\Code\testing\test_output\ckpt\checkpoint.pth
# 23
# Finish inference for sample No.0
# 24
# Finish inference for sample No.1
# 25
# Finish inference for sample No.2
# 26
# Finish inference for sample No.3
# 27
# Finish inference for sample No.4
# 76
# Finish inference for sample No.5
# 77
# Finish inference for sample No.6
# 78
# Finish inference for sample No.7
# 79
# Finish inference for sample No.8
# 80
# Finish inference for sample No.9
# corners - precision: 0.000 recall: 0.000 f_score: 0.000
# edges - precision: 0.000 recall: 0.000 f_score: 0.000
# regions - precision: 0.000 recall: 0.000 f_score: 0.000
# Avg prec: 0.0, Avg recall: 0.0
# Load from ckpts of epoch 239
# test
# Loaded saved model from C:\Users\sigbj\Documents\Master\Code\testing\test_output\ckpt\checkpoint.pth
# 92
# Finish inference for sample No.0
# 93
# Finish inference for sample No.1
# 94
# ...

# %%
from heat.infer import main
root_path = r'test_output/reproject_set'
ckpt_path = r'C:\Users\sigbj\Documents\Master\Code\testing\test_output\ckpt\checkpoint_best194.pth'
id = str(16618)
data_path = root_path + '/' + id 
det_path = data_path + '/det'
viz_base = data_path + r'\results\rgb'
save_base = data_path + r'\results\viz'   
main(data_path=data_path,
        det_path=det_path,
        ckpt_path=ckpt_path,
        viz_base=viz_base,
        save_base=save_base)
# Out:
# Load from ckpts of epoch 194
# Loaded saved model from C:\Users\sigbj\Documents\Master\Code\testing\test_output\ckpt\checkpoint_best194.pth
# 93
# Finish inference for sample No.0
# 94
# Finish inference for sample No.1
# 95
# Finish inference for sample No.2
# 96
# Finish inference for sample No.3
# 97
# Finish inference for sample No.4
# corners - precision: 0.833 recall: 1.000 f_score: 0.909
# edges - precision: 0.875 recall: 1.000 f_score: 0.933
# regions - precision: 1.000 recall: 1.000 f_score: 1.000
# Avg prec: 0.438974358974359, Avg recall: 0.9333333333333333
# ([array([[[ 47,  59,  40],
#           [ 56,  69,  51],
#           [ 68,  80,  62],
#           ...,
#           [105, 113, 104],
#           [ 89,  97,  88],
#           [ 71,  79,  69]],
#
#          [[ 60,  72,  54],
#           [ 64,  76,  58],
#           [ 68,  80,  62],
#           ...,
#           [113, 121, 111],
#           [107, 115, 105],
#           [ 97, 105,  96]],
#
#          [[ 71,  83,  65],
# ...
